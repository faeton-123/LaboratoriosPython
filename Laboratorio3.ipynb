# %% [markdown]
# # **Laboratorio 3: Análisis de datos con Python**

# %% [markdown]
# ### Parte 1: Numpy:

# %% [markdown]
# ### **(1)**
#
# ¿Cuál es el tamaño en bytes de un array de 1000
# elementos de tipo booleano?

# %% [markdown]
# ### **(2)**
# Cree un array cuyos elementos sean los enteros pares en
# [1,100] y en orden decreciente. Muestre los 10 últimos
# por pantalla.

# %%
import numpy as np

array_par = np.arange(100,0,-2)  # arange permite crear el array en un rango seleccionado 0-100, el -2 para que sea par
array_pantalla = array_par[40:]
print(array_pantalla)
# Out:
# [20 18 16 14 12 10  8  6  4  2]

# %% [markdown]
# ### **(3)**
# Dado un array selecciona con una instruccion el subarray de elemento 0,3,7,4

# %%
array_dado = [[2, 4, 5, 6],[0, 3, 7, 4],[8, 8, 5, 2],[1, 5, 6, 1]]
subarray1 = array_dado[1][0:4]
print(subarray1)
# Out:
# [0, 3, 7, 4]

# %%
subarray2 = [[array_dado[0][0], array_dado[0][2]], [array_dado[2][1], array_dado[2][2]]]
print(subarray2)
# Out:
# [[2, 5], [8, 5]]

# %% [markdown]
# ### **(4)**
# Dados los arrays a = [1, 4, 2, 7] y b = [1, 3, 2, 9], obtenga la media aritmética de la diferencia (a-b).

# %%
import statistics #se carga la libreria statics

a = [1, 4, 2, 7] 
b = [1, 3, 2, 9]

diferencia = [a[i] - b[i] for i in range(len(a))]
media = statistics.mean(diferencia)

print("La media aritmetica de la diferncia (a-b) es:", media)
# Out:
# La media aritmetica de la diferncia (a-b) es: -0.25

# %% [markdown]
# ### (5)
# Tengo valores de cordenadas (x, y) en las columnas
# del array
# 1.33 4.5
# 30.0 10.7
# 70.2 0.5

# %%
import numpy as np

coordenadas = [[1.33, 4.5], [30.0, 10.7], [70.2, 0.5]] # coordenadas dadas

nueva_fila = np.array([37.1, -3.6]) #agregar nueva fila
coordenadas = np.vstack([coordenadas, nueva_fila])

# Imprimir las dimensiones del nuevo array
print("Las dimensiones del array modificado son:", coordenadas.shape) #se usa shape para que nos de la dimension y coordenasa
print(coordenadas)
# Out:
# Las dimensiones del array modificado son: (4, 2)
# [[ 1.33  4.5 ]
#  [30.   10.7 ]
#  [70.2   0.5 ]
#  [37.1  -3.6 ]]

# %% [markdown]
# ### **(6)**
#  Copie el array del ejercicio anterior. Traspóngalo y Agregue ahora dos nuevos pares de coordenadas: (10.8, 3.0) y (35.8, 12.0).

# %%
import numpy as np

nueva_fila2 = np.array([10.8, 3.0]) #agregar nueva fila
coordenadas = np.vstack([coordenadas, nueva_fila2])

nueva_fila3 = np.array([35.8, 12.0]) #agregar nueva fila
coordenadas = np.vstack([coordenadas, nueva_fila3])

transpuesta = coordenadas.transpose() #para transponer

print("el array mas las filas agregadas")
print(coordenadas)
print("el array transpuesto")
print(transpuesta)
# Out:
# el array mas las filas agregadas
# [[ 1.33  4.5 ]
#  [30.   10.7 ]
#  [70.2   0.5 ]
#  [37.1  -3.6 ]
#  [10.8   3.  ]
#  [10.8   3.  ]
#  [35.8  12.  ]
#  [10.8   3.  ]
#  [35.8  12.  ]
#  [10.8   3.  ]
#  [35.8  12.  ]]
# el array transpuesto
# [[ 1.33 30.   70.2  37.1  10.8  10.8  35.8  10.8  35.8  10.8  35.8 ]
#  [ 4.5  10.7   0.5  -3.6   3.    3.   12.    3.   12.    3.   12.  ]]

# %% [markdown]
# ### Parte 2: Exploracion y minería de Datos:

# %% [markdown]
# Con el dataset nucleospoblacion.csv adjunto al laboratorio, luego responda las siguientes preguntas usando pandas y matplotlib.

# %% [markdown]
# #### **(1)**
# ¿Cuántos Municipios tienen más de 100000
# habitantes?.

# %%
import pandas as pd

data = pd.read_csv('NucleosPoblacion.csv')
municipios_mayor_100k = data.loc[data['Poblacion'] > 100000] # Selecciona las filas con población mayor a 100000
num_municipios_mayor_100k = len(municipios_mayor_100k) # cuenta el número de filas seleccionadas
print("Numero de municipios con mas de 100000 habitantes")
print(num_municipios_mayor_100k)
# Out:
# Numero de municipios con mas de 100000 habitantes
# 62

# %% [markdown]
# ### **(2)**
# Realice una gráfica de barras sobre la población de cada ciudad, ordenela de menor a mayor y responda:

# %%
data_sorted = data.sort_values(by='Poblacion') #Ordena los datos usando la columna poblacion
fig, ax = plt.subplots() # para crear el grafico
ax.bar(data_sorted['Texto'], data_sorted['Poblacion']) # hace la grafica

ax.set_title('Población de cada ciudad') # para añadir los titulos
ax.set_xlabel('Ciudad')
ax.set_ylabel('Población')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show() # imprime la grafica

# %% [markdown]
# ### **(a).**
# ¿Cuál es la segunda ciudad más poblada?

# %%
data_sorted = data.sort_values(by="Poblacion", ascending=False)# ordena los datos de la columan poblacion en orden descendente
segunda_ciudad = data_sorted.iloc[1]["Texto"] # obtiene la poblacion de la segunda ciudad
poblacion_segunda_ciudad = data_sorted.iloc[1]["Poblacion"]
print("La segunda ciudad más poblada es", segunda_ciudad, "con una población de", poblacion_segunda_ciudad) #imprimir
# Out:
# La segunda ciudad más poblada es Barcelona con una población de 1619337.0

# %% [markdown]
# ### **(b).**
# ¿Qué posición ocupa Granada en el ranking de las ciudades más pobladas?

# %%
granada = data.loc[data['Texto'] == 'Granada'] # busca granada en la columna Texto
data_sorted = data.sort_values(by='Poblacion', ascending=False)# Ordena  la columna  población de manera descendente
posicion_granada = data_sorted.index.get_loc(granada.index[0]) # Obtiene la posicion Granada en los datos
print("La ciudad de Granada está en la posición", posicion_granada+1, "respecto a la población.")
# Out:
# La ciudad de Granada está en la posición 18 respecto a la población.

# %% [markdown]
# ### **(7)**
# Seleccione al azar cincuenta municipios diferentes de entre los diponibles en el archivo. Asegúrese de que no se repitan. ¿Luego calcule el promedio de la población y la desviación estándar de esto 50 municipios?.

# %%
municipios_aleatorios = data['Municipio'].sample(n=50, replace=False) #elige de la columna municipios, 50 aleatorios

# calcula la media y desviación estándar de la población
poblaciones = data.loc[data['Municipio'].isin(municipios_aleatorios)]['Poblacion']
media_poblacion = poblaciones.mean()
desviacion_estandar_poblacion = poblaciones.std()

print("Promedio de la población:", media_poblacion)
print("Desviación estándar de la población:", desviacion_estandar_poblacion)
# Out:
# Promedio de la población: 46062.5873015873
# Desviación estándar de la población: 74564.70650351924
